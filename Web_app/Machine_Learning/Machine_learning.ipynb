# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('amazon.csv')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# #EXPLORATORY DATA ANALYSIS

# %%
df['rating_count'].head()
# Out:
# 0    24,269
# 1    43,994
# 2     7,928
# 3    94,363
# 4    16,905
# Name: rating_count, dtype: object

# %%
#fill or drop missing values
df['rating_count']=df['rating_count'].str.replace(',','').astype(float)
df['rating_count'].fillna(df['rating_count'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1465 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Check unique values or sample values in the 'rating' column
print(df['rating'].unique())
# Out:
# ['4.2' '4.0' '3.9' '4.1' '4.3' '4.4' '4.5' '3.7' '3.3' '3.6' '3.4' '3.8'
#  '3.5' '4.6' '3.2' '5.0' '4.7' '3.0' '2.8' '4' '3.1' '4.8' '2.3' '|' '2'
#  '3' '2.6' '2.9']

# %%
print(df['rating'].unique())

# Clean 'rating' column
df['rating'] = df['rating'].replace('[\|]', '', regex=True)
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')

# Fill NaN values if any
df['rating'].fillna(df['rating'].median(), inplace=True)

# Convert other columns as necessary
df['actual_price'] = df['actual_price'].replace('[₹,\$]', '', regex=True).astype(float)
df['discount_percentage'] = df['discount_percentage'].replace('[\%,]', '', regex=True).astype(float)
df['rating_count'] = df['rating_count'].astype(int)

# Verify the conversion
print(df['rating'].dtype)
print(df['rating'].head())
# Out:
# ['4.2' '4.0' '3.9' '4.1' '4.3' '4.4' '4.5' '3.7' '3.3' '3.6' '3.4' '3.8'
#  '3.5' '4.6' '3.2' '5.0' '4.7' '3.0' '2.8' '4' '3.1' '4.8' '2.3' '|' '2'
#  '3' '2.6' '2.9']
# float64
# 0    4.2
# 1    4.0
# 2    3.9
# 3    4.2
# 4    4.2
# Name: rating, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   int32
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df['sub_category']=df['category'].astype(str).str.split('|').str[-1]
df['main_category']=df['category'].astype(str).str.split('|').str[0]
df['rating_weighted']=df['rating']*df['rating_count']

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64'])

# %%
# Strip leading and trailing spaces from string columns
for col in df.columns:
    if df[col].dtype == 'object':  # Check if the column is of type object (string)
        df[col] = df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df.describe()
# Out:
#         actual_price  discount_percentage       rating   rating_count  \
# count    1465.000000          1465.000000  1465.000000    1465.000000
# mean     5444.990635            47.691468     4.096587   18277.634812
# std     10874.826864            21.635905     0.291574   42727.398216
# min        39.000000             0.000000     2.000000       2.000000
# 25%       800.000000            32.000000     4.000000    1191.000000
# 50%      1650.000000            50.000000     4.100000    5179.000000
# 75%      4295.000000            63.000000     4.300000   17325.000000
# max    139900.000000            94.000000     5.000000  426973.000000
#
#        rating_weighted
# count     1.465000e+03
# mean      7.613989e+04
# std       1.800456e+05
# min       4.000000e+00
# 25%       4.760100e+03
# 50%       2.152000e+04
# 75%       7.103250e+04
# max       1.878681e+06

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2         24269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1465 non-null   int32
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2         24269
# ...

# %% [markdown]
# #DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['actual_price'], bins=30, edgecolor='k', alpha=0.7)
plt.title('Distribution of Actual Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['discount_percentage'], bins=30, edgecolor='k', alpha=0.7, color='orange')
plt.title('Distribution of Discount Percentages')
plt.xlabel('Discount Percentage')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['rating_count'], bins=30, edgecolor='k', alpha=0.7, color='green')
plt.title('Number of Reviews per Product')
plt.xlabel('Number of Reviews')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(1,3,figsize=(20,8))

fig.suptitle('Rating & Amount of Ratings Distribution', fontweight='heavy', size='large')

sns.histplot(ax=ax[0],data=df, x='rating', bins=15, kde=True, color='blue')
sns.histplot(ax=ax[1],data=df, x='rating_count', bins=15, kde=True, color='red')
sns.histplot(ax=ax[2],data=df, x='rating_weighted', bins=15, kde=True, color='green')

ax[0].set_xlabel('Ratings')
ax[1].set_xlabel('Number of Ratings')
ax[2].set_xlabel('Weighted Ratings')

ax[0].set_ylabel('Number of Products')
ax[1].set_ylabel('Number of Products')
ax[2].set_ylabel('Number of Products')

ax[0].set_title('Distribution of Ratings', fontweight='bold')
ax[1].set_title('Distribution of Count Ratings', fontweight='bold')
ax[2].set_title('Distribution of Weighted Ratings', fontweight='bold')

plt.show()

# %%
df.describe()
# Out:
#         actual_price  discount_percentage       rating   rating_count  \
# count    1465.000000          1465.000000  1465.000000    1465.000000
# mean     5444.990635            47.691468     4.096587   18277.634812
# std     10874.826864            21.635905     0.291574   42727.398216
# min        39.000000             0.000000     2.000000       2.000000
# 25%       800.000000            32.000000     4.000000    1191.000000
# 50%      1650.000000            50.000000     4.100000    5179.000000
# 75%      4295.000000            63.000000     4.300000   17325.000000
# max    139900.000000            94.000000     5.000000  426973.000000
#
#        rating_weighted
# count     1.465000e+03
# mean      7.613989e+04
# std       1.800456e+05
# min       4.000000e+00
# 25%       4.760100e+03
# 50%       2.152000e+04
# 75%       7.103250e+04
# max       1.878681e+06

# %%
fig, ax = plt.subplots(1,3,figsize=(20,8))

fig.suptitle('Rating & Amount of Ratings Distribution', fontweight='heavy', size='large')

sns.boxplot(ax=ax[0],data=df, x='rating',color='red')
sns.boxplot(ax=ax[1],data=df, x='rating_count',  color='blue')
sns.boxplot(ax=ax[2],data=df, x='rating_weighted', color='green')

ax[0].set_xlabel('Ratings')
ax[1].set_xlabel('Number of Ratings')
ax[2].set_xlabel('Weighted Ratings')

ax[0].set_ylabel('Number of Products')
ax[1].set_ylabel('Number of Products')
ax[2].set_ylabel('Number of Products')

ax[0].set_title('Distribution of Ratings', fontweight='bold')
ax[1].set_title('Distribution of Count Ratings', fontweight='bold')
ax[2].set_title('Distribution of Weighted Ratings', fontweight='bold')

plt.show()

# %%
# Create table with values per cluster
bins = [0, 1, 2, 3, 4, 5] # Define bin edges
df['rating_bin'] = pd.cut(df['rating'], bins=bins, include_lowest=True, labels=['0-1', '1-2', '2-3', '3-4', '4-5'])
rate_bin = df['rating_bin'].value_counts().reset_index()
rate_bin = rate_bin.sort_values('count')

# %%
mean_top = df.groupby('main_category')['rating'].mean().sort_values(ascending=False).reset_index()
mean_top['rating'] = np.round(mean_top['rating'],2)

plt.figure(figsize=(10, 6))

ax = sns.barplot(x='rating', y='main_category', data=mean_top, palette='viridis')
ax.set_xlabel('Mean Rating')
ax.set_ylabel('Main Category')
ax.set_title('Top Rated by Average Main Categories')
ax.bar_label(ax.containers[0])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['actual_price'], bins=30)
plt.title('Distribution of Actual Price')

plt.subplot(1, 2, 2)
sns.histplot(df['discounted_price'], bins=30)
plt.title('Distribution of Discounted Price')

plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['rating'], bins=20)
plt.title('Distribution of Ratings')
plt.show()

# %%
sns.histplot(data=df,x='discount_percentage',bins=8,kde=True,color='green')
plt.xlabel('Discount %')
plt.ylabel('Number of products')
plt.title('Distribution of Discount %')
plt.show()

# %%
import plotly.express as px
import pandas as pd


# Group by 'main_category' and calculate the mean of 'discount_pecentage'
pie1 = df.groupby('main_category')['discount_percentage'].mean().sort_values(ascending=False).reset_index()
pie_plot1 = pie1.head(8)  # Get the top 8 categories

# Create a pie chart using Plotly Express
fig = px.pie(pie_plot1,
             values='discount_percentage',
             names='main_category',
             title='Average Discount % per Main Category',
             labels={'discount_percentage': 'Average Discount %', 'main_category': 'Main Category'},
             hole=0.3)  # Adding a hole creates a donut chart

# Update layout for better aesthetics
fig.update_layout(
    title_font=dict(size=20, family='Arial', color='black'),
    legend_title=dict(text='Main Category'),
    legend=dict(orientation='h', yanchor='bottom', xanchor='center', x=0.5, y=-0.2)
)

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Get the mean discount percentage by sub-category for the top 15 sub-categories
mean_discount_top_15 = df.groupby('sub_category')['discount_percentage'].mean().sort_values(ascending=False).head(15)
mean_discount_top_15 = np.round(mean_discount_top_15,2)

# Create the bar plot using Seaborn
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=mean_discount_top_15.values, y=mean_discount_top_15.index, palette='viridis')
plt.title('Top 15 Sub Categories by Discount Percentage')
plt.xlabel('Discount Percentage')
plt.ylabel('Sub Category')
ax.bar_label(ax.containers[0])
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_cols.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                      actual_price  discount_percentage    rating  \
# actual_price             1.000000            -0.118098  0.121636
# discount_percentage     -0.118098             1.000000 -0.155273
# rating                   0.121636            -0.155273  1.000000
# rating_weighted         -0.035704             0.010494  0.114536
#
#                      rating_weighted
# actual_price               -0.035704
# discount_percentage         0.010494
# rating                      0.114536
# rating_weighted             1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
pairplot = sns.pairplot(numeric_cols, kind='reg',
                        plot_kws={'line_kws':{'color':'red'}})
plt.show()

# %% [markdown]
# #TEXTBLOB FOR SENTIMENTAL ANALYSIS

# %% [markdown]
# from surprise import SVDpp, Dataset, Reader
# from surprise.model_selection import train_test_split
# from surprise.model_selection import GridSearchCV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from surprise import SVDpp, Dataset, Reader
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import TextBlob
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder
from wordcloud import WordCloud
from surprise.accuracy import rmse, mae

# %%
from surprise import SVDpp, Dataset, Reader
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV

# %%
 #Classify Sentiment
def sentiment(text):
    analysis = TextBlob(text)
    # threshold for positive & negetive polarity
    if analysis.sentiment.polarity > 0.1:
        return 'Positive'
    elif analysis.sentiment.polarity < -0.1:
        return 'Negative'
    else:
        return 'Neutral'


# apply sentiment analysis on review_content

total_review = df['review_content'] + df['review_title'] # Join together review title and contents for better analysis
sentimen = total_review.apply(sentiment)
sentiment_count = sentimen.value_counts()

# plot the bar

ax = sentiment_count.plot(kind='bar',color=['#00CED1','#800080','#DAA520'])

for i in ax.patches:
    ax.text(i.get_x() + i.get_width() / 2, i.get_height() + 0.05, str(i.get_height()), ha='center', va='bottom')


ax.set_title('Sentiment on Reviews',fontweight='bold',size=14)

plt.xlabel('Sentiments')
plt.ylabel('Number of Reviews')
plt.show()

# %% [markdown]
# SMOTE OVERSAMPLING ANALYSIS TO BALANCE THE IMBALANCED DATA

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Resampled class distribution (example data)
resampled_counts = pd.Series({
    'Neutral': 970,
    'Negative': 970,
    'Positive': 970
})

# Plot the resampled class distribution
plt.figure(figsize=(8, 6))
bars = plt.bar(resampled_counts.index, resampled_counts.values, color=['#00CED1', '#800080', '#DAA520'])

# Add labels and titles
plt.xlabel('Sentiments')
plt.ylabel('Number of Reviews')
plt.title('Sentiment Distribution After SMOTE', fontweight='bold', size=14)

# Add text labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 20, int(yval), ha='center', va='bottom')

plt.show()

# %%
reviews_text = ' '.join(df['review_content'].dropna().values + df['review_title'].dropna().values)
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(reviews_text)

# %%
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
# Filter only Good Rating Reviews and get the Features of Items
high_rating = df[df['rating'] >= 4.0]

# Create a string of all the reviews for these products
desc_text = ' '.join(high_rating['about_product'].dropna().values)

# Generate the wordcloud
wordcloud = WordCloud(width=800, height=800, background_color='white', min_font_size=10).generate(desc_text)

# Plot the wordcloud
plt.figure(figsize=(8, 8), facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
reviewer_name = df['user_name'].str.split(",")
reviewer_id = df['user_id'].str.split(",")

# %%
reviewer_name = reviewer_name.explode().reset_index(drop=True)
reviewer_id = reviewer_id.explode().reset_index(drop=True)

# %%
reviewer=pd.DataFrame({'reviewer_id':reviewer_id,'reviewer_name':reviewer_name})

# %%
reviewer.head()
# Out:
#                     reviewer_id   reviewer_name
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q           Manav
# 1  AHMY5CWJMMK5BJRBBSNLYT3ONILA    Adarsh gupta
# 2  AHCTC6ULH4XB6YHDY6PCH2R772LQ         Sundeep
# 3  AGYHHIERNXKA6P5T7CZLXKVPT7IQ  S.Sayeed Ahmed
# 4  AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q  jaspreet singh

# %%
reviewer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11515 entries, 0 to 11514
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewer_id    11503 non-null  object
#  1   reviewer_name  11515 non-null  object
# dtypes: object(2)
# memory usage: 180.0+ KB

# %%
reviewer['reviewer_id'].value_counts().sort_values(ascending=False).head(10).rename_axis('username').reset_index(name='Number of Reviews')
# Out:
#                        username  Number of Reviews
# 0  AG5DWPD54QGSLWJ6QUFERLPNAX4Q                 11
# 1  AE55KTFVNXYFD5FPYWP2OUPEYNPQ                 11
# 2  AECPFYFQVRUWC3KGNLJIOREFP5LQ                 10
# 3  AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA                 10
# 4  AHMGAC6QM62UXNEOCZIHLHSXPP2Q                 10
# 5  AFHROSCGIXUPV3FYQ7H5QOD46Q7Q                 10
# 6  AEAMIR3CMSA32IDEINSJKHRNANTA                 10
# 7  AF355FTXYAKFH5NYPRTE7SL3WO3Q                 10
# 8  AEBWA5I4QFCA3P3OBEPMELBGN4GQ                 10
# 9  AFV7ZA733ZLME4KNLZPMPCBUNPPA                  9

# %%
reviewer.shape
# Out:
# (11515, 2)

# %%
top10reviewers = reviewer['reviewer_name'].value_counts().sort_values(ascending=False).head(10).rename_axis('username').reset_index(name='Number of Reviews')

# %%
ax = sns.barplot(data = top10reviewers,y ='username',x ='Number of Reviews',palette='CMRmap')
ax.set_xlabel('Number of Reviews')
ax.set_ylabel('Username')
ax.set_title('Top 10 Active Reviewers',size=16,fontweight='medium')
ax.bar_label(ax.containers[0])
plt.grid(False)
plt.show()

# %%
user_le=LabelEncoder()
df['user_id']=user_le.fit_transform(df['user_id'])
item_le=LabelEncoder()
df['item_id']=item_le.fit_transform(df['product_id'])

# %%
# Remove duplicates based on 'user_id_encoded'
df = df.drop_duplicates(subset='user_id', keep='first')

# Remove duplicates based on 'item_id_encoded'
df = df.drop_duplicates(subset='item_id', keep='first')

# %%
df['combined_reviews']=df['review_title'] + " " + df['review_content']

# %%
df['combined_reviews'].head()
# Out:
# 0    Satisfied,Charging is really fast,Value for mo...
# 1    A Good Braided Cable for Your Type C Device,Go...
# 2    Good speed for earlier versions,Good Product,W...
# 3    Good product,Good one,Nice,Really nice product...
# 4    As good as original,Decent,Good one for second...
# Name: combined_reviews, dtype: object

# %%
def analyze_sentiment_to_rating(text):
    # Analyzing the sentiment of the text
    blob = TextBlob(text)
    polarity = blob.sentiment.polarity  # Polarity score ranges from -1 (negative) to 1 (positive)

    # Converting polarity to a 1-5 rating scale
    # Mapping -1 as 1, 0 as 3, and 1 as 5
    rating = round((polarity + 1) * 2) + 1  # Scales and shifts the polarity to fit 1-5
    return max(min(rating, 5), 1)  # Ensures the rating stays within the range of 1 to 5

# %%
df['combined_features'] = df['product_name'] + " " + df['main_category'] + " " + df['sub_category'] + " " + df['about_product']

# %%
df['combined_features'].head()
# Out:
# 0    Wayona Nylon Braided USB to Lightning Fast Cha...
# 1    Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2    Sounce Fast Phone Charging Cable & Data Sync U...
# 3    boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4    Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# Name: combined_features, dtype: object

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                 64.0     4.2         24269
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1186 entries, 0 to 1464
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1186 non-null   object
#  1   product_name         1186 non-null   object
#  2   category             1186 non-null   object
#  3   discounted_price     1186 non-null   object
#  4   actual_price         1186 non-null   float64
#  5   discount_percentage  1186 non-null   float64
#  6   rating               1186 non-null   float64
#  7   rating_count         1186 non-null   int64
#  8   about_product        1186 non-null   object
#  9   user_id              1186 non-null   int64
#  10  user_name            1186 non-null   object
#  11  review_id            1186 non-null   object
#  12  review_title         1186 non-null   object
#  13  review_content       1186 non-null   object
#  14  img_link             1186 non-null   object
# ...

# %% [markdown]
# # NATURAL LANGUAGE PROCESSING

# %%
# Download stopwords if not already downloaded
nltk.download('punkt')
nltk.download('stopwords')

def preprocess_text(text):
    # Lowercasing
    text = text.lower()

    # Removing punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Tokenization
    tokens = word_tokenize(text)

    # Removing stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in tokens]

    preprocessed_text = ' '.join(stemmed_tokens)

    return preprocessed_text

# Assuming df is your DataFrame and 'combined_reviews' is the combined text column
df['preprocessed_combined_reviews'] = df['combined_reviews'].apply(preprocess_text)

# Example output
print(df[['combined_reviews', 'preprocessed_combined_reviews']].head())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                     combined_reviews  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                        preprocessed_combined_reviews
# 0  satisfiedcharg realli fastvalu moneyproduct re...
# 1  good braid cabl type c devicegood qualiti prod...
# 2  good speed earlier versionsgood productwork go...
# 3  good productgood onenicer nice productveri fir...
# 4  good originaldecentgood one secondari usebest ...

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Combine all preprocessed reviews into a single text
all_text = ' '.join(df['preprocessed_combined_reviews'])

# Tokenize the combined text
all_tokens = word_tokenize(all_text)

# Count word frequencies
word_freq = Counter(all_tokens)

# Get the most common words
most_common_words = word_freq.most_common(20)

# Plot the most common words
words, counts = zip(*most_common_words)
plt.figure(figsize=(12, 8))
plt.bar(words, counts)
plt.xticks(rotation=45)
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Top 20 Most Common Words')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1186 entries, 0 to 1464
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_id                     1186 non-null   object
#  1   product_name                   1186 non-null   object
#  2   category                       1186 non-null   object
#  3   discounted_price               1186 non-null   object
#  4   actual_price                   1186 non-null   float64
#  5   discount_percentage            1186 non-null   float64
#  6   rating                         1186 non-null   float64
#  7   rating_count                   1186 non-null   int64
#  8   about_product                  1186 non-null   object
#  9   user_id                        1186 non-null   int64
#  10  user_name                      1186 non-null   object
#  11  review_id                      1186 non-null   object
# ...

# %% [markdown]
# # LSTM_NEURAL NETWORK

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load your dataset
# df = pd.read_csv('your_dataset.csv')  # Replace with your dataset path

# Use the 'preprocessed_combined_reviews' column for text data
texts = df['preprocessed_combined_reviews']
labels = df['sentiment_encoded']

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(texts, labels, test_size=0.3, random_state=42)

# Tokenize the text data
tokenizer = Tokenizer(num_words=5000)  # Use top 5000 words
tokenizer.fit_on_texts(X_train)

# Convert texts to sequences
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# Pad sequences to ensure uniform input size
max_len = 100  # Maximum length of sequences
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=5000, output_dim=128, input_length=max_len))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))  # Assuming 3 sentiment classes

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train_pad, y_train, epochs=10, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 127ms/step - accuracy: 0.7893 - loss: 0.9057 - val_accuracy: 0.9458 - val_loss: 0.2623
# Epoch 2/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - accuracy: 0.9351 - loss: 0.3272 - val_accuracy: 0.9458 - val_loss: 0.2395
# Epoch 3/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.9314 - loss: 0.3049 - val_accuracy: 0.9458 - val_loss: 0.2428
# Epoch 4/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9270 - loss: 0.3183 - val_accuracy: 0.9458 - val_loss: 0.2414
# Epoch 5/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9233 - loss: 0.3403 - val_accuracy: 0.9458 - val_loss: 0.2408
# Epoch 6/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - accuracy: 0.9333 - loss: 0.2971 - val_accuracy: 0.9458 - val_loss: 0.2420
# Epoch 7/10
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9363 - loss: 0.2688 - val_accuracy: 0.9458 - val_loss: 0.2409
# Epoch 8/10
# ...

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test_pad, y_test)
print(f"Test Accuracy: {test_accuracy:.4f}")

# Plot training & validation accuracy and loss
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.9289 - loss: 0.2657
# Test Accuracy: 0.9270

# %% [markdown]
# # RECOMMENDATION SYSTEM

# %%
# Applying the sentiment analysis function to convert reviews to ratings
df['derived_rating'] = df['preprocessed_combined_reviews'].apply(analyze_sentiment_to_rating)

# Display the DataFrame with the new ratings
print(df[['review_content', 'derived_rating']])
# Out:
#                                          review_content  derived_rating
# 0     Looks durable Charging is fine tooNo complains...               4
# 1     I ordered this cable to connect my phone to An...               3
# 2     Not quite durable and sturdy,https://m.media-a...               4
# 3     Good product,long wire,Charges good,Nice,I bou...               4
# 4     Bought this instead of original apple, does th...               4
# ...                                                 ...             ...
# 1460  I received product without spanner,Excellent p...               4
# 1461  ok,got everything as mentioned but the measuri...               3
# 1462  plastic but cool body ,u have to find sturdy s...               4
# 1463  I have installed this in my kitchen working fi...               3
# 1464  It does it job perfectly..only issue is temp c...               4
#
# [1186 rows x 2 columns]

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['user_id', 'item_id', 'derived_rating']], reader)

# %%
# Hyperparameter Tuning
param_grid_svdpp = {
    'n_epochs': [10, 20, 30, 40, 50],  # Increasing the number of epochs to see if longer training improves results
    'n_factors': [20, 50, 100, 200],  # Expanding the range to test smaller and larger spaces of factors
    'lr_all': [0.001, 0.003, 0.005, 0.007, 0.01],  # Adding a lower learning rate for finer adjustments
    'reg_all': [0.01, 0.02, 0.05, 0.1]  # Adjusting regularization to capture both underfitting and overfitting scenarios
}

# %%
 #Cross Validation
gs_svdpp = GridSearchCV(SVDpp, param_grid_svdpp, measures=['rmse', 'mae'], cv=5)

gs_svdpp.fit(data)
print('Best SVDpp parameters:', gs_svdpp.best_params['rmse'])
# Out:
# Best SVDpp parameters: {'n_epochs': 10, 'n_factors': 20, 'lr_all': 0.001, 'reg_all': 0.01}

# %%
# Train-test split
# Convert Surprise Dataset to a compatible format for train_test_split
from surprise.model_selection import train_test_split as surprise_train_test_split

trainset, testset = surprise_train_test_split(data, test_size=0.2, random_state=42)

# Re-train the best models on the full training set
best_svdpp = gs_svdpp.best_estimator['rmse']
best_svdpp.fit(trainset)

# Evaluate on the training set
train_predictions_svdpp = best_svdpp.test(trainset.build_testset())
print('Training Set - SVDpp RMSE:', rmse(train_predictions_svdpp))
print('Training Set - SVDpp MAE:', mae(train_predictions_svdpp))

# Evaluate on the testing set
test_predictions_svdpp = best_svdpp.test(testset)
print('Testing Set - SVDpp RMSE:', rmse(test_predictions_svdpp))
print('Testing Set - SVDpp MAE:', mae(test_predictions_svdpp))
# Out:
# RMSE: 0.4585
# Training Set - SVDpp RMSE: 0.4585231964322971
# MAE:  0.4057
# Training Set - SVDpp MAE: 0.4057029935816327
# RMSE: 0.4846
# Testing Set - SVDpp RMSE: 0.484607425668676
# MAE:  0.4337
# Testing Set - SVDpp MAE: 0.4336949969861363

# %%
with open('best_svdpp_model.pkl', 'wb') as model_file:
    pickle.dump(best_svdpp, model_file)
print('Model saved to best_svdpp_model.pkl')

# %%
import pickle

# Load the model
with open('best_svdpp_model.pkl', 'rb') as model_file:
    loaded_model = pickle.load(model_file)

print('Model loaded from best_svdpp_model.pkl')

# %%
# RMSE and MAE values
metrics = {
    'SVDpp': {'RMSE': rmse(test_predictions_svdpp), 'MAE': mae(test_predictions_svdpp)}
}

# Labels for the metrics
labels = list(metrics.keys())
metrics_values = metrics['SVDpp']
metrics_names = list(metrics_values.keys())
values = [metrics_values[metric] for metric in metrics_names]

# X locations for the groups
x = range(len(metrics_names))

# Plotting RMSE and MAE
plt.figure(figsize=(10, 6))
bars = plt.bar(x, values, width=0.4, align='center', alpha=0.7, color=['blue', 'orange'])

# Adding text labels on bars
for bar, value in zip(bars, values):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 0.05, f'{value:.2f}', ha='center', color='white', fontsize=14)

# Adding labels and title
plt.xlabel('Metrics')
plt.ylabel('Value')
plt.title('Evaluation Metrics for SVDpp Model')
plt.xticks(x, metrics_names)
plt.legend(labels)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# RMSE: 0.4846
# MAE:  0.4337

# %%
import pandas as pd
from surprise import SVDpp  # Make sure to import your specific model
from surprise import Dataset, Reader

# Example mapping DataFrame (replace this with your actual mapping)
item_mapping_df = pd.DataFrame({
    'Item ID Encoded': [367, 735, 588, 484, 916],
    'product_id': ['P001', 'P002', 'P003', 'P004', 'P005']
})

# Example: Generate item recommendations for a specific user
user_id = int(input("Enter user_id: "))
top_n = 5  # Number of recommendations to generate

# Get the list of all item IDs (This should be based on your actual trainset)
item_ids = list(trainset.all_items())

# Predict ratings for all items for the target user and store scores
user_ratings_sorted = []
for item_id in item_ids:
    prediction = best_svdpp.predict(user_id, item_id)
    user_ratings_sorted.append((item_id, prediction.est))  # Store only the predicted rating

# Sort the predicted ratings in descending order based on the scores
user_ratings_sorted = sorted(user_ratings_sorted, key=lambda x: x[1], reverse=True)

# Select the top-N items with the highest predicted ratings
recommended_items = [(item_id, score) for item_id, score in user_ratings_sorted[:top_n]]  # Extract item ID and score

# Convert recommendations to DataFrame
collab_recom = pd.DataFrame(recommended_items, columns=['Item ID Encoded', 'Score'])

# Merge recommendations with the item mapping DataFrame to decode the item IDs
collab_recom = collab_recom.merge(item_mapping_df, on='Item ID Encoded')

# Print recommendations with original item IDs
print(f"Top {top_n} Recommendations for User {user_id}:")
print("--------------------------------------------")
print(collab_recom[['product_id', 'Score']])
# Out:
# Enter user_id: 678
# Top 5 Recommendations for User 678:
# --------------------------------------------
#   product_id     Score
# 0       P001  3.859811
# 1       P002  3.858925
# 2       P003  3.851726
# 3       P004  3.842464
# 4       P005  3.834170

# %%
def recommend_products(df, user_id_encoded):
    # Use TfidfVectorizer to transform the product descriptions into numerical feature vectors
    tfidf = TfidfVectorizer(stop_words='english')
    df['combined_features'] = df['combined_features'].fillna('')  # fill NaN values with empty string
    tfidf_matrix = tfidf.fit_transform(df['combined_features'])

    # Get the purchase history for the user
    user_history = df[df['user_id'] == user_id_encoded]

    if not user_history.empty:
        # Indices of the user's history products
        indices = user_history.index.tolist()

        # Calculate the cosine similarity for the products user has interacted with against all products
        cosine_sim_user = cosine_similarity(tfidf_matrix[indices], tfidf_matrix)

        # Flatten the matrix and remove self similarities
        flat_cosine_sim = cosine_sim_user.flatten()
        top_indices = sorted(((i, sim) for i, sim in enumerate(flat_cosine_sim) if i not in indices), key=lambda x: x[1], reverse=True)

        # Select the top 5 recommended products excluding self similarity
        top_products = top_indices[:5]

        # Fetch recommended product details
        recommended_products = df.iloc[[i[0] for i in top_products]]
        results_df = pd.DataFrame({
            'Id Encoded': [user_id] * 5,
            'Product ID': recommended_products['product_id'].tolist(),
            'Item ID Encoded': recommended_products['item_id'].tolist(),
            'Recommended Product': recommended_products['product_name'].tolist(),
            'Score Recommendation': [i[1] for i in top_products]
        })

        return results_df
    else:
        print("No purchase history found.")
        return None

# %%
content = recommend_products(df, 141)
content
# Out:
#    Id Encoded  Product ID  Item ID Encoded  \
# 0         678  B09GB5B4BK              905
# 1         678  B073BRXPZX              237
# 2         678  B083RD1J99              531
# 3         678  B09ZHCJDP1             1121
# 4         678  B004IO5BMQ                4
#
#                                  Recommended Product  Score Recommendation
# 0  HP 150 Wireless USB Mouse with Ergonomic and a...              0.322931
# 1  Lenovo 300 Wired Plug & Play USB Mouse, High R...              0.309029
# 2  HP Wired Mouse 100 with 1600 DPI Optical Senso...              0.306799
# 3  Amazon Basics Wireless Mouse | 2.4 GHz Connect...              0.288036
# 4  Logitech M235 Wireless Mouse, 1000 DPI Optical...              0.278079
